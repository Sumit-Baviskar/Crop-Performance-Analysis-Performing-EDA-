# %% [markdown]
# # **Performing Exploratory Data Analysis (EDA) on Agriculture Crop Yield**
#
# ---

# %% [markdown]
# #**Introduction to Exploratory Data Analysis (EDA)**
#
# ---
#
#
#
# **Exploratory Data Analysis (EDA)** is a crucial step in any data analysis project. It involves investigating datasets to summarize their main characteristics, often using visualization methods.
#
#
#
#
# The **purpose of EDA** is to:
#
# **1) Understand the structure of the data**
#
# **2) Detect outliers and anomalies**
#
# **3) Identify missing values**
#
# **4) Find important variables and patterns**
#
#
# Form hypotheses for further analysis
# In this project, EDA will help provide a solid understanding of the data and guide the next steps, such as cleaning, transforming, and modeling the data.
#
#
#
#
#
#
# The **key objectives** for this EDA process include:
#
#
# **1) Understanding the data distribution:** Identifying the underlying distributions of the variables to inform future analyses.
#
# **2) Data cleaning and preparation:** Dealing with any missing or anomalous data points that could impact the analysis.
#
# **3) Identifying patterns and trends:** Using visualizations and statistical summaries to discover relationships within the data.
#
# **4)Hypothesis generation:** Developing preliminary insights that can be tested with more formal analysis later on.

# %% [markdown]
# ###**Author :**  [**Sumit Baviskar**](https://www.linkedin.com/in/sumit-baviskar/)

# %% [markdown]
# ###**Dataset  :** [**Agriculture Crop Yeild**](https://www.kaggle.com/datasets/samuelotiattakorah/agriculture-crop-yield?resource=download)

# %% [markdown]
# #**About Dataset**
#
# This dataset contains agricultural data for 1,000,000 samples aimed at predicting crop yield (in tons per hectare) based on various factors. The dataset can be used for regression tasks in machine learning, especially for predicting crop productivity.
#
#
#
# - **Region:** The geographical region where the crop is grown (North, East, South, West).
#
#
#
#
# - **Soil_Type:** The type of soil in which the crop is planted (Clay, Sandy, Loam, Silt, Peaty, Chalky).
#
#
#
# - **Crop:** The type of crop grown (Wheat, Rice, Maize, Barley, Soybean, Cotton).
#
#
#
# - **Rainfall_mm:** The amount of rainfall received in millimeters during the crop growth period.
#
#
#
# - **Temperature_Celsius:** The average temperature during the crop growth period, measured in degrees Celsius.
#
#
# - **Fertilizer_Used:** Indicates whether fertilizer was applied (True = Yes, False = No).
#
#
#
# - **Irrigation_Used:** Indicates whether irrigation was used during the crop growth period (True = Yes, False = No).
#
#
#
# - **Weather_Condition:** The predominant weather condition during the growing season (Sunny, Rainy, Cloudy).
#
#
#
# - **Days_to_Harvest:** The number of days taken for the crop to be harvested after planting.
#
#
#
# - **Yield_tons_per_hectare:** The total crop yield produced, measured in tons per hectare.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/crop_yield.csv")  #Reading file

# %%
df.head()  #Checking head
# Out:
#   Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0   West     Sandy   Cotton   897.077239            27.676966
# 1  South      Clay     Rice   992.673282            18.026142
# 2  North      Loam   Barley   147.998025            29.794042
# 3  North     Sandy  Soybean   986.866331            16.644190
# 4  South      Silt    Wheat   730.379174            31.620687
#
#    Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0            False             True            Cloudy              122
# 1             True             True             Rainy              140
# 2            False            False             Sunny              106
# 3            False             True             Rainy              146
# 4             True             True            Cloudy              110
#
#    Yield_tons_per_hectare
# 0                6.555816
# 1                8.527341
# 2                1.127443
# 3                6.517573
# 4                7.248251

# %%
df.shape  #Checking shape. They are 1000000 rows and 10 columns
# Out:
# (1000000, 10)

# %%
df.columns  #Checking columns -- Column Names
# Out:
# Index(['Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius',
#        'Fertilizer_Used', 'Irrigation_Used', 'Weather_Condition',
#        'Days_to_Harvest', 'Yield_tons_per_hectare'],
#       dtype='object')

# %%
df.info()   #information aboout the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Region                  1000000 non-null  object
#  1   Soil_Type               1000000 non-null  object
#  2   Crop                    1000000 non-null  object
#  3   Rainfall_mm             1000000 non-null  float64
#  4   Temperature_Celsius     1000000 non-null  float64
#  5   Fertilizer_Used         1000000 non-null  bool
#  6   Irrigation_Used         1000000 non-null  bool
#  7   Weather_Condition       1000000 non-null  object
#  8   Days_to_Harvest         1000000 non-null  int64
#  9   Yield_tons_per_hectare  1000000 non-null  float64
# dtypes: bool(2), float64(3), int64(1), object(4)
# memory usage: 62.9+ MB

# %% [markdown]
# #**Data Types**
#
# The **data types** in a dataset are generally categorized into two main types:
#
#
#  - **Numeric**
#
#
#  - **Categorical**.
#
#
#
#
#
#
#
#  ## **Numeric data :**
#
#
#   - includes variables that represent measurable quantities, such as age, income, or height. These can be further divided into continuous (e.g., weight) and discrete (e.g., number of products sold) data.
#
#
#
# ## **Categorical data :**
#
#
#
# - consists of variables that represent distinct groups or categories, such as gender, product type, or region. These can be either nominal (no inherent order, like colors or cities) or ordinal (with a specific order, like ratings from 1 to 5).
#
#
#
#
#
# By separating the data into these two types, we can better understand the structure of the dataset. This separation allows for more tailored analysis and helps in **identifying patterns, trends, and inconsistencies** within the data. It also assists in detecting potential errors that may need correction.
#
#
#
# Ultimately,  this approach helps answer the key questions targeted in the analysis by providing clear insights into how different variables interact.

# %%
# Numeric Data columns
df.select_dtypes(exclude=["object","bool"])
# Out:
#         Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# 0        897.077239            27.676966              122
# 1        992.673282            18.026142              140
# 2        147.998025            29.794042              106
# 3        986.866331            16.644190              146
# 4        730.379174            31.620687              110
# ...             ...                  ...              ...
# 999995   302.805345            27.987428               76
# 999996   932.991383            39.661039               93
# 999997   867.362046            24.370042              108
# 999998   492.812857            33.045505              102
# 999999   180.936180            27.298847               76
#
#         Yield_tons_per_hectare
# 0                     6.555816
# 1                     8.527341
# 2                     1.127443
# 3                     6.517573
# 4                     7.248251
# ...                        ...
# 999995                1.347586
# 999996                7.311594
# 999997                5.763182
# 999998                2.070159
# 999999                2.937243
#
# [1000000 rows x 4 columns]

# %%
numeric_column=df.select_dtypes(exclude=["object","bool"]).columns  #Getting numeric columns
numeric_column
# Out:
# Index(['Rainfall_mm', 'Temperature_Celsius', 'Days_to_Harvest',
#        'Yield_tons_per_hectare'],
#       dtype='object')

# %%
df.describe()  #Checking description for numeric data
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %% [markdown]
# ##**Handling Null Values**
#
# If there are null values in
#
# **1) Numeric columns** then we can use **Imputation techniques by using -- mean, median and mode** as per requirements
#
# **2) Categorical data** -- we can drop that row

# %%
df.isnull().sum()  #Checking null values. They are sum null values we can drop them as in next step
# Out:
# Region                    0
# Soil_Type                 0
# Crop                      0
# Rainfall_mm               0
# Temperature_Celsius       0
# Fertilizer_Used           0
# Irrigation_Used           0
# Weather_Condition         0
# Days_to_Harvest           0
# Yield_tons_per_hectare    0
# dtype: int64

# %%
# For categorical data ,We can drop
df=df.dropna()  #Droping null values

# %%
df.isnull().sum().sum()  #Checking null values after dropping
# Out:
# 0

# %% [markdown]
# #**Finding outliers :**

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,4,1)
sns.boxplot(df["Rainfall_mm"],color="g") # mean can be used as there are no outliers to fill null values (as mean is effected by outliers)
plt.title("Rainfall_mm boxplot")
plt.subplot(1,4,2)
sns.boxplot(df["Temperature_Celsius"],color="g") # mean can be used as there are no outliers to fill null values (as mean is effected by outliers)
plt.title("Temperature_Celsius boxplot")
plt.subplot(1,4,3)
sns.boxplot(df["Days_to_Harvest"],color="g") # mean can be used as there are no outliers to fill null values (as mean is effected by outliers)
plt.title("Days_to_Harvest boxplot")
plt.subplot(1,4,4)
sns.boxplot(df["Yield_tons_per_hectare"],color="g") # mode can be used as there are outliers to fill null values (as mean is effected by outliers)
plt.title("Yield_tons_per_hectare boxplot")
# Out:
# Text(0.5, 1.0, 'Yield_tons_per_hectare boxplot')

# %% [markdown]
# ##**Key Observations:**
#
# ###**Rainfall (mm):**
#
# - Median rainfall is **around 600 mm.**
#
# - The range spans from **approximately 100 mm to 1000 mm.**
#
#
#
# ###**Temperature (Celsius):**
#
# - Median temperature is **around 30°C.**
#
#
# -Temperature values range **between 15°C to 40°C, with no outliers.**
#
#
#
# ###**Days to Harvest:**
#
# - Median days to harvest is **close to 100.**
#
#
#
# - The range is approximately **from 60 to 140 days.**
#
#
# ###**Yield (Tons per Hectare):**
#
# -  Median yield is **about 4.5 tons per hectare.**
#
#
# -  A few outliers are present **below 1 ton per hectare,** but there are no significant outliers on the upper end.
#
#
# - The range is **from 0 to just below 10 tons per hectare.**

# %% [markdown]
# ##**Insights:**
#
#
# - Rainfall is the most critical factor for yield based on the strong positive correlation.
#
#
# - Temperature and days to harvest seem to have negligible impact on crop yield in this particular dataset.
#
#
# - The presence of outliers in yield (below 1 ton per hectare) could indicate unusual conditions or errors that require further investigation.

# %% [markdown]
# # **Exploring Numeric Data**

# %% [markdown]
# ###**Imputation techniques** --> using mean,median and mode to replace the null values
# For example if there are null in **Temperature_Celsius** or **Rainfall_mm**column
# we can use mean or median to fill the null values

# %%
df["Temperature_Celsius"]=df["Temperature_Celsius"].fillna(int(df["Temperature_Celsius"].median()))

#OR

df["Temperature_Celsius"]=df["Temperature_Celsius"].fillna(int(df["Temperature_Celsius"].mean()))

#OR

df["Rainfall_mm"]=df["Rainfall_mm"].fillna(int(df["Rainfall_mm"].mode()))

# %%
df[numeric_column].median() # calculating median
# Out:
# Rainfall_mm               550.124061
# Temperature_Celsius        27.507365
# Days_to_Harvest           104.000000
# Yield_tons_per_hectare      4.651808
# dtype: float64

# %% [markdown]
# #**Observation:**
#
#
# - **Median** of Rainfall_mm is higher than Days_to_Harvest,Temperature_Celsius with larger range and Yield_tons_per_hectare has lowest median with also the lowest range .
#
#
#
# - So we can say the spread of data or **variance or standard deviation** is for Rainfall_mm and  Yield_tons_per_hectare has lowest variance or standard deviation

# %%
df[numeric_column].std()  # calculating standard deviation
# Out:
# Rainfall_mm               259.851320
# Temperature_Celsius         7.220608
# Days_to_Harvest            25.953412
# Yield_tons_per_hectare      1.696572
# dtype: float64

# %%
df[numeric_column].var()  # calculating variance
# Out:
# Rainfall_mm               67522.708650
# Temperature_Celsius          52.137174
# Days_to_Harvest             673.579609
# Yield_tons_per_hectare        2.878358
# dtype: float64

# %%
sns.boxplot(df["Yield_tons_per_hectare"],color="g")  #Outliers in Yield_tons_per_hectare
# Out:
# <Axes: ylabel='Yield_tons_per_hectare'>

# %% [markdown]
# ##**Treating Outliers**

# %%
# Using IQR(Interquartile range)
# Percentile
# IQR=Q3-Q1 (range of middle 50% of the data)

# %%
df.describe()["Yield_tons_per_hectare"]
# Out:
# count    1000000.000000
# mean           4.649472
# std            1.696572
# min           -1.147613
# 25%            3.417637
# 50%            4.651808
# 75%            5.879200
# max            9.963372
# Name: Yield_tons_per_hectare, dtype: float64

# %%
Q3=df.describe()["Yield_tons_per_hectare"]["75%"]
Q3
# Out:
# 5.879200097141489

# %%
Q1=df.describe()["Yield_tons_per_hectare"]["25%"]
Q1
# Out:
# 3.417637434469158

# %%
IQR=Q3-Q1
IQR
# Out:
# 2.4615626626723306

# %%
Lower_limit=Q1-1.5*IQR
Upper_limit=Q3+1.5*IQR

# %%
Lower_limit,Upper_limit
# Out:
# (-0.2747065595393381, 9.571544091149985)

# %%
# To check the Outliers
#df=df[(df["Age"]>Upper_limit)|(df["Age"]<Lower_limit)] # to check outliers

# %%
df=df[(df["Yield_tons_per_hectare"]>=Lower_limit)&(df["Yield_tons_per_hectare"]<=Upper_limit)] # Filtering the Outliers

# %%
df.describe()  #Summarizing
# Out:
#          Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  999916.000000        999916.000000    999916.000000
# mean      549.993840            27.505137       104.494819
# std       259.833685             7.220490        25.953254
# min       100.000896            15.000034        60.000000
# 25%       324.926150            21.254918        82.000000
# 50%       550.136596            27.507644       104.000000
# 75%       774.732054            33.753267       127.000000
# max       999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count           999916.000000
# mean                 4.649618
# std                  1.695999
# min                 -0.274296
# 25%                  3.417837
# 50%                  4.651861
# 75%                  5.879131
# max                  9.570438

# %%
df[numeric_column].corr()  #Checking Correlation
sns.heatmap(df[numeric_column].corr(),annot=True,cmap='Greens', linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# ##**Key Observations:**
#
# - Yield_tons_per_hectare has the **highest correlation** related to all other factors like Days_to_Harvest, Temperature_Celsius, Rainfall_mm and Temperature_Celsius has the **lowest correlation** to all other factors.
#
#
#
# -  Days_to_Harvest is **negatively correlated (but value is too close to zero)** to
# Rainfall_mm, Temperature_Celsius, Yield_tons_per_hectare - it can be said it is there are not corelated  .
#
#
#
# - Yield_tons_per_hectare is **positively correlated** to Rainfall_mm and Temperature_Celsius . So we can concluded more rainfall and tempertaure can leads to more crop yield per hectare tonnes.

# %% [markdown]
# ###**Rainfall and Yield:**
#
# There is a **strong positive correlation (+0.76) between rainfall and yield**, indicating that more rainfall tends to increase crop yield.
#
#
# ###**Other Variables:**
#
# - There is **weak or negligible** correlation **between temperature, days to harvest, and yield.**
#
#
# - Temperature has a **slight positive correlation with yield (+0.085)**, but it is not significant enough to conclude any strong relationship.
#
#
# - There is **no significant relationship between days to harvest** and other variables.

# %% [markdown]
# # **Exploring Categorical Data**

# %%
#Categorical Data
df.select_dtypes(include=["object","bool"])
# Out:
#        Region Soil_Type     Crop  Fertilizer_Used  Irrigation_Used  \
# 0        West     Sandy   Cotton            False             True
# 1       South      Clay     Rice             True             True
# 2       North      Loam   Barley            False            False
# 3       North     Sandy  Soybean            False             True
# 4       South      Silt    Wheat             True             True
# ...       ...       ...      ...              ...              ...
# 999995   West      Silt     Rice            False            False
# 999996  South    Chalky   Barley             True            False
# 999997  North     Peaty   Cotton             True            False
# 999998   West      Silt    Wheat            False            False
# 999999   West     Sandy    Maize             True            False
#
#        Weather_Condition
# 0                 Cloudy
# 1                  Rainy
# 2                  Sunny
# 3                  Rainy
# 4                 Cloudy
# ...                  ...
# 999995             Sunny
# 999996             Rainy
# 999997            Cloudy
# 999998             Sunny
# 999999             Sunny
#
# [999916 rows x 6 columns]

# %%
#Categorical Data
categorical_column=df.select_dtypes(include=["object","bool"]).columns
categorical_column
# Out:
# Index(['Region', 'Soil_Type', 'Crop', 'Fertilizer_Used', 'Irrigation_Used',
#        'Weather_Condition'],
#       dtype='object')

# %%
df["Region"].value_counts().sort_values(ascending=False)
# Out:
# Region
# North    250152
# West     250047
# South    250036
# East     249681
# Name: count, dtype: int64

# %% [markdown]
# **There more cases from north region followed by west, south and east.**

# %%
df["Soil_Type"].value_counts().sort_values(ascending=False)
# Out:
# Soil_Type
# Sandy     167105
# Loam      166780
# Chalky    166762
# Silt      166663
# Clay      166335
# Peaty     166271
# Name: count, dtype: int64

# %% [markdown]
# **There most common soil types in this study is Sandy followed by Loam and Chalky and least cases is for Peaty soil type**

# %%
df["Crop"].value_counts().sort_values(ascending=False)
# Out:
# Crop
# Maize      166813
# Rice       166782
# Barley     166762
# Wheat      166652
# Cotton     166569
# Soybean    166338
# Name: count, dtype: int64

# %% [markdown]
# **Seams likes there are 6 crop types in our dataset -- Maize, rice,barley, wheat, cotton and soybean**

# %%
df["Irrigation_Used"].value_counts().sort_values(ascending=False)
# Out:
# Irrigation_Used
# False    500453
# True     499463
# Name: count, dtype: int64

# %% [markdown]
# **There are less irrigation used  in our study records than irrigation used records can consider that more crop are grown are rainfed crop.**

# %%
df["Weather_Condition"].value_counts().sort_values(ascending=False)
# Out:
# Weather_Condition
# Sunny     333761
# Rainy     333533
# Cloudy    332622
# Name: count, dtype: int64

# %% [markdown]
# **More crop are grown in Sunny condition followed by rainy and cloudy with least cases**

# %%
plt.figure(figsize=(20,6))
plt.subplot(2,3,1)
df["Region"].value_counts().plot(kind="pie",autopct="%1.1f%%",colors = ['palegreen', 'lightgreen', 'mediumseagreen', 'seagreen', 'forestgreen', 'darkgreen'])
plt.title("Region")
plt.subplot(2,3,2)
df["Soil_Type"].value_counts().plot(kind="pie",autopct="%1.1f%%",colors = ['palegreen', 'lightgreen', 'mediumseagreen', 'seagreen', 'forestgreen', 'darkgreen'])
plt.title("Soil_Type")
plt.subplot(2,3,3)
df["Crop"].value_counts().plot(kind="pie",autopct="%1.1f%%",colors = ['palegreen', 'lightgreen', 'mediumseagreen', 'seagreen', 'forestgreen', 'darkgreen'])
plt.title("Crop")
plt.subplot(2,3,4)
df["Fertilizer_Used"].value_counts().plot(kind="pie",autopct="%1.1f%%",colors = ['forestgreen',"mediumseagreen"])
plt.title("Fertilizer_Used")
plt.subplot(2,3,5)
df["Irrigation_Used"].value_counts().plot(kind="pie",autopct="%1.1f%%",colors = ['mediumseagreen',"forestgreen"])
plt.title("Irrigation_Used")
plt.subplot(2,3,6)
df["Weather_Condition"].value_counts().plot(kind="pie",autopct="%1.1f%%",colors = ['seagreen',"mediumseagreen","green"])
plt.title("Weather_Condition")
# Out:
# Text(0.5, 1.0, 'Weather_Condition')

# %% [markdown]
# #**Key Observations**
#
# ##**1.Region Distribution (Top Left Pie Chart):**
#
# - All four regions (North, South, East, West) have equal representation, each occupying 25% of the data.
#
#
# ##**2.Soil Type Distribution (Top Middle Pie Chart):**
#
# - The soil types (Loam, Sandy, Peaty, Clay, Silt, Chalky) are equally distributed, with each type occupying approximately 16.7% of the data.
#
#
# ##**3.Crop Distribution (Top Right Pie Chart):**
#
# - Crops (Rice, Maize, Soybean, Cotton, Wheat, Barley) are equally distributed, with each type accounting for around 16.7% of the data.
#
#
# ##**4.Fertilizer Usage (Bottom Left Pie Chart):**
#
#
# - Exactly 50% of the data points have used fertilizer, while 50% have not.
#
#
# ##**5.Irrigation Usage (Bottom Middle Pie Chart):**
#
#
# - Similar to fertilizer, 50% of the data points have used irrigation, while 50% have not.
#
#
# ##**6.Weather Conditions (Bottom Right Pie Chart):**
#
#
# - The data is divided almost equally into three weather conditions: Sunny (33.4%), Cloudy (33.3%), and Rainy (33.4%).
#
#
#
# #**Insight:**
#
#
# - **Distributions of regions, soil types, crops, and weather conditions are all balancedin the given dataset.**

# %%
# Categorical Data we can use value count
pd.set_option('display.max_rows', None)
result_1=df[categorical_column].value_counts().sort_values(ascending=False)
result_1
# Out:
# Region  Soil_Type  Crop     Fertilizer_Used  Irrigation_Used  Weather_Condition
# North   Silt       Maize    False            False            Sunny                661
#                    Cotton   False            True             Sunny                653
# South   Peaty      Wheat    True             True             Cloudy               650
# North   Loam       Maize    True             False            Sunny                648
# South   Sandy      Rice     True             False            Cloudy               647
# North   Silt       Wheat    True             True             Rainy                644
# East    Chalky     Cotton   True             True             Sunny                643
# South   Clay       Rice     True             True             Sunny                640
# West    Loam       Maize    True             False            Rainy                640
#         Clay       Rice     False            True             Rainy                639
# South   Silt       Wheat    True             True             Sunny                639
# East    Peaty      Barley   True             True             Sunny                639
# West    Chalky     Cotton   True             False            Rainy                638
# South   Sandy      Rice     False            False            Rainy                638
# North   Chalky     Soybean  True             False            Cloudy               638
# East    Silt       Maize    True             False            Sunny                638
# West    Peaty      Barley   True             True             Rainy                637
#         Chalky     Cotton   False            True             Rainy                635
# East    Chalky     Barley   False            False            Rainy                634
# South   Sandy      Cotton   False            False            Cloudy               633
# East    Sandy      Cotton   True             False            Sunny                632
# North   Chalky     Soybean  False            True             Rainy                632
# South   Loam       Cotton   True             False            Cloudy               631
#         Chalky     Maize    False            True             Rainy                631
#         Sandy      Soybean  True             False            Sunny                631
# East    Chalky     Soybean  False            False            Sunny                631
# South   Sandy      Cotton   False            False            Sunny                631
# North   Loam       Barley   False            True             Rainy                630
# South   Silt       Rice     True             False            Sunny                630
# West    Peaty      Wheat    False            False            Rainy                629
# East    Chalky     Wheat    True             False            Cloudy               629
# North   Clay       Barley   False            False            Cloudy               628
# East    Sandy      Soybean  False            True             Cloudy               627
# West    Peaty      Maize    False            False            Sunny                627
# South   Clay       Rice     False            False            Cloudy               627
# North   Loam       Barley   True             True             Rainy                627
# West    Loam       Barley   True             False            Cloudy               626
# North   Sandy      Maize    True             True             Rainy                626
# East    Peaty      Cotton   False            False            Cloudy               626
# North   Chalky     Maize    True             False            Cloudy               626
# West    Chalky     Soybean  True             True             Sunny                626
# North   Peaty      Cotton   True             True             Rainy                626
# East    Chalky     Maize    False            False            Sunny                626
# West    Sandy      Wheat    True             False            Cloudy               625
# North   Sandy      Wheat    True             True             Sunny                625
# East    Silt       Rice     True             False            Sunny                625
#         Loam       Cotton   False            True             Sunny                624
# North   Chalky     Soybean  False            False            Rainy                623
# South   Clay       Soybean  False            False            Rainy                623
# West    Silt       Rice     True             True             Sunny                623
# North   Sandy      Barley   True             False            Cloudy               623
# South   Loam       Maize    True             True             Sunny                622
# West    Peaty      Wheat    True             False            Rainy                622
# South   Loam       Maize    True             True             Rainy                622
# North   Clay       Rice     False            False            Rainy                622
#         Chalky     Wheat    False            True             Rainy                622
# West    Sandy      Barley   True             False            Sunny                621
# North   Loam       Barley   False            False            Sunny                621
# West    Chalky     Soybean  False            True             Cloudy               621
# East    Loam       Soybean  True             False            Sunny                621
#         Chalky     Soybean  False            False            Rainy                621
#         Silt       Cotton   True             True             Rainy                620
# North   Loam       Rice     True             True             Rainy                620
#         Sandy      Rice     True             False            Cloudy               620
# South   Silt       Soybean  False            False            Cloudy               620
# North   Silt       Maize    False            True             Sunny                620
# East    Clay       Maize    False            False            Sunny                620
#         Chalky     Wheat    False            True             Rainy                620
# West    Sandy      Soybean  True             True             Cloudy               619
#         Peaty      Maize    False            False            Cloudy               619
# South   Loam       Soybean  True             True             Rainy                619
# East    Silt       Cotton   False            True             Cloudy               619
# North   Clay       Barley   False            False            Sunny                619
# South   Silt       Wheat    True             True             Cloudy               618
# West    Loam       Cotton   False            False            Sunny                618
#         Peaty      Rice     True             False            Cloudy               618
# East    Silt       Soybean  True             True             Sunny                618
# South   Silt       Cotton   True             False            Sunny                618
# North   Silt       Cotton   True             False            Sunny                618
#         Clay       Maize    False            True             Cloudy               618
# South   Clay       Barley   False            False            Cloudy               617
# North   Peaty      Barley   True             False            Sunny                617
# East    Silt       Soybean  False            False            Cloudy               617
#         Sandy      Rice     False            False            Sunny                617
# South   Peaty      Wheat    True             False            Sunny                617
#                    Soybean  False            True             Sunny                617
#         Chalky     Soybean  False            False            Cloudy               617
# West    Silt       Rice     False            False            Sunny                617
#         Chalky     Rice     False            True             Rainy                616
#         Silt       Barley   False            False            Rainy                616
# East    Sandy      Barley   False            False            Rainy                616
# North   Sandy      Maize    False            True             Rainy                616
# East    Clay       Maize    True             False            Sunny                616
# West    Silt       Barley   True             True             Cloudy               616
# East    Peaty      Soybean  False            True             Rainy                616
# North   Chalky     Rice     True             False            Rainy                616
# West    Silt       Barley   False            True             Sunny                616
# East    Sandy      Soybean  True             False            Sunny                615
# West    Silt       Barley   False            True             Rainy                615
# North   Chalky     Wheat    True             False            Cloudy               615
#                    Cotton   True             True             Rainy                615
#         Silt       Wheat    True             True             Sunny                615
# West    Chalky     Barley   False            True             Sunny                615
# East    Chalky     Cotton   True             False            Sunny                615
#                    Rice     True             False            Cloudy               615
# South   Peaty      Cotton   False            False            Sunny                615
# North   Peaty      Barley   True             False            Rainy                615
#         Chalky     Rice     False            False            Cloudy               614
# West    Loam       Rice     True             True             Rainy                614
# North   Chalky     Soybean  False            True             Cloudy               614
# West    Clay       Rice     False            False            Sunny                614
#         Silt       Soybean  True             True             Rainy                614
# East    Clay       Soybean  False            False            Sunny                614
#         Sandy      Soybean  False            True             Rainy                614
#         Peaty      Rice     False            False            Cloudy               614
# South   Loam       Cotton   True             False            Rainy                613
# East    Clay       Cotton   True             True             Rainy                613
# West    Clay       Maize    False            True             Cloudy               613
# East    Clay       Barley   False            True             Rainy                613
#         Peaty      Soybean  True             True             Rainy                613
#         Sandy      Barley   False            True             Sunny                613
#         Clay       Maize    False            False            Cloudy               613
# North   Loam       Wheat    True             False            Cloudy               613
# West    Silt       Cotton   False            False            Rainy                613
# North   Clay       Cotton   False            True             Sunny                613
# East    Sandy      Soybean  False            False            Rainy                613
# North   Loam       Wheat    True             True             Cloudy               613
# South   Chalky     Barley   True             True             Cloudy               613
# East    Sandy      Cotton   True             True             Sunny                613
# South   Chalky     Maize    True             False            Cloudy               613
#         Loam       Barley   True             True             Rainy                613
# East    Sandy      Barley   False            True             Cloudy               612
#         Peaty      Barley   False            True             Cloudy               612
# West    Loam       Cotton   True             False            Rainy                612
# South   Peaty      Rice     True             False            Cloudy               612
# East    Sandy      Cotton   True             True             Cloudy               612
# West    Silt       Soybean  False            True             Cloudy               612
# East    Sandy      Rice     False            False            Rainy                612
# West    Peaty      Soybean  False            False            Sunny                612
# North   Peaty      Wheat    False            False            Sunny                612
# East    Silt       Rice     True             True             Cloudy               612
# West    Chalky     Soybean  True             False            Cloudy               612
# North   Silt       Wheat    False            False            Rainy                612
# West    Clay       Wheat    True             True             Sunny                612
#         Sandy      Wheat    False            True             Cloudy               612
# North   Sandy      Barley   True             False            Rainy                611
#         Chalky     Cotton   True             False            Cloudy               611
# South   Loam       Maize    True             False            Cloudy               611
# West    Clay       Barley   False            False            Rainy                611
# South   Loam       Maize    False            False            Cloudy               611
# West    Peaty      Maize    True             False            Rainy                611
# South   Clay       Barley   True             False            Sunny                611
# North   Clay       Rice     True             False            Sunny                611
# South   Loam       Barley   True             True             Cloudy               611
# East    Loam       Soybean  True             True             Rainy                611
# West    Sandy      Rice     True             True             Rainy                611
# South   Chalky     Cotton   True             True             Sunny                611
# North   Sandy      Wheat    True             False            Cloudy               611
# West    Loam       Cotton   True             True             Sunny                610
# North   Loam       Cotton   False            True             Rainy                610
#                    Barley   True             False            Rainy                610
#         Clay       Maize    False            False            Rainy                610
# South   Peaty      Barley   True             False            Cloudy               610
# East    Silt       Soybean  True             False            Cloudy               610
# South   Chalky     Rice     False            False            Cloudy               610
# East    Loam       Cotton   True             True             Sunny                610
# South   Peaty      Barley   True             True             Cloudy               610
# West    Chalky     Barley   False            False            Rainy                610
# North   Peaty      Rice     False            True             Sunny                610
# West    Sandy      Rice     False            False            Sunny                610
#         Chalky     Wheat    False            True             Cloudy               610
# North   Loam       Wheat    False            True             Sunny                610
#         Silt       Rice     False            False            Cloudy               609
# West    Loam       Maize    False            True             Cloudy               609
# North   Clay       Rice     True             True             Sunny                609
# West    Chalky     Cotton   True             False            Sunny                609
# North   Silt       Barley   True             True             Cloudy               609
# East    Sandy      Wheat    True             False            Cloudy               609
# North   Silt       Wheat    False            True             Rainy                609
# South   Clay       Wheat    False            False            Sunny                609
# North   Chalky     Barley   True             True             Rainy                609
# South   Silt       Soybean  False            True             Sunny                608
#         Loam       Cotton   False            False            Rainy                608
#         Sandy      Rice     True             False            Sunny                608
# East    Peaty      Cotton   False            True             Sunny                608
# West    Silt       Cotton   False            False            Cloudy               608
# North   Clay       Soybean  True             False            Rainy                608
# South   Silt       Soybean  True             True             Sunny                608
# East    Loam       Rice     True             True             Sunny                608
# North   Chalky     Barley   True             True             Sunny                608
# West    Loam       Maize    True             True             Cloudy               608
# South   Loam       Barley   True             False            Sunny                608
# West    Silt       Maize    False            True             Cloudy               608
# East    Sandy      Barley   False            False            Sunny                607
# West    Loam       Wheat    True             False            Cloudy               607
# South   Sandy      Maize    False            True             Rainy                607
# West    Clay       Cotton   False            True             Sunny                607
# East    Chalky     Soybean  True             True             Rainy                607
# North   Sandy      Rice     False            False            Cloudy               607
# West    Loam       Wheat    False            False            Cloudy               607
# South   Chalky     Barley   False            False            Rainy                607
# West    Chalky     Barley   False            False            Sunny                607
#         Clay       Soybean  True             True             Cloudy               607
# North   Loam       Barley   False            False            Rainy                607
# West    Loam       Wheat    True             False            Sunny                607
# North   Loam       Rice     True             True             Sunny                606
# East    Clay       Cotton   False            True             Cloudy               606
# South   Silt       Maize    True             False            Sunny                606
# North   Clay       Cotton   False            True             Cloudy               606
#         Chalky     Wheat    False            True             Cloudy               606
# East    Loam       Rice     False            False            Rainy                606
# South   Silt       Wheat    False            True             Sunny                606
#         Loam       Rice     False            False            Rainy                606
#         Chalky     Rice     False            True             Rainy                606
# West    Chalky     Maize    False            False            Sunny                606
# East    Chalky     Maize    True             False            Rainy                606
# West    Loam       Maize    True             True             Sunny                605
# South   Loam       Maize    False            False            Rainy                605
#         Clay       Cotton   True             False            Sunny                605
# East    Sandy      Maize    False            False            Sunny                605
# North   Sandy      Cotton   False            False            Sunny                605
# East    Sandy      Barley   True             True             Sunny                605
# South   Chalky     Maize    False            False            Sunny                605
# North   Silt       Rice     True             False            Sunny                605
# West    Peaty      Cotton   False            False            Sunny                605
# East    Clay       Barley   False            True             Sunny                605
#                    Rice     False            False            Rainy                605
# North   Silt       Maize    True             True             Sunny                605
# West    Sandy      Soybean  True             True             Sunny                604
# North   Clay       Rice     False            False            Sunny                604
#         Peaty      Wheat    True             True             Rainy                604
# East    Sandy      Wheat    True             True             Rainy                604
# North   Silt       Barley   False            False            Sunny                604
# West    Peaty      Maize    False            True             Sunny                604
#         Sandy      Cotton   True             True             Rainy                604
# North   Peaty      Barley   False            True             Rainy                604
# West    Peaty      Wheat    False            False            Cloudy               604
#         Sandy      Soybean  False            False            Rainy                604
#         Silt       Cotton   True             True             Sunny                604
#         Peaty      Wheat    True             True             Rainy                604
# East    Chalky     Maize    True             True             Cloudy               604
#         Loam       Barley   False            False            Rainy                604
# North   Silt       Maize    False            False            Cloudy               604
# South   Sandy      Wheat    True             True             Sunny                604
# North   Sandy      Wheat    False            False            Sunny                604
# South   Clay       Wheat    False            False            Rainy                604
# North   Chalky     Soybean  True             True             Sunny                604
# South   Peaty      Barley   False            True             Sunny                604
# North   Chalky     Barley   True             False            Rainy                604
#         Silt       Maize    False            True             Rainy                603
# West    Chalky     Rice     True             True             Sunny                603
# East    Loam       Rice     False            True             Cloudy               603
#         Silt       Cotton   False            True             Sunny                603
# West    Silt       Soybean  True             False            Sunny                603
#                             False            False            Rainy                603
#                    Rice     True             False            Rainy                603
#         Loam       Barley   False            True             Cloudy               603
# East    Loam       Cotton   False            True             Cloudy               603
# South   Peaty      Maize    False            False            Rainy                603
# West    Silt       Maize    True             False            Cloudy               603
# South   Loam       Maize    False            True             Sunny                603
# West    Peaty      Wheat    True             True             Cloudy               603
# East    Peaty      Cotton   True             False            Rainy                603
#         Silt       Maize    False            True             Rainy                603
#                             True             False            Rainy                603
# South   Silt       Wheat    False            False            Sunny                603
# West    Peaty      Rice     False            True             Rainy                603
# East    Clay       Soybean  True             True             Cloudy               603
# North   Silt       Rice     True             False            Cloudy               603
# South   Loam       Rice     False            False            Cloudy               603
# West    Loam       Barley   True             True             Rainy                603
# South   Chalky     Wheat    True             True             Sunny                603
# North   Silt       Soybean  True             False            Cloudy               603
# East    Clay       Rice     False            True             Sunny                603
# North   Silt       Barley   False            True             Sunny                602
# South   Chalky     Soybean  True             True             Sunny                602
# East    Peaty      Soybean  False            True             Cloudy               602
# West    Sandy      Wheat    False            False            Sunny                602
#                             True             True             Cloudy               602
# East    Peaty      Barley   True             False            Cloudy               602
# West    Clay       Soybean  False            False            Rainy                602
# East    Peaty      Maize    False            True             Rainy                602
# West    Loam       Rice     True             False            Rainy                602
# North   Peaty      Soybean  True             True             Cloudy               602
#         Clay       Wheat    True             True             Cloudy               602
# South   Sandy      Barley   False            False            Rainy                602
#                    Wheat    False            True             Cloudy               602
# North   Chalky     Maize    False            True             Rainy                602
# South   Sandy      Barley   False            True             Rainy                602
# North   Loam       Soybean  False            True             Rainy                602
# South   Silt       Cotton   True             True             Cloudy               601
# North   Silt       Cotton   False            False            Sunny                601
# South   Loam       Soybean  False            True             Sunny                601
# North   Loam       Cotton   False            False            Sunny                601
#         Clay       Wheat    False            True             Cloudy               601
#         Loam       Maize    False            True             Sunny                601
#         Chalky     Rice     True             False            Cloudy               601
#         Peaty      Wheat    False            True             Rainy                601
# West    Loam       Cotton   False            False            Rainy                601
# East    Sandy      Maize    True             False            Rainy                601
# South   Loam       Cotton   False            True             Sunny                601
# West    Chalky     Barley   True             False            Rainy                601
#         Sandy      Maize    True             True             Sunny                601
# East    Loam       Maize    False            True             Sunny                601
# North   Loam       Maize    True             True             Rainy                601
# West    Clay       Barley   False            True             Sunny                600
# North   Silt       Wheat    True             False            Sunny                600
# East    Clay       Rice     False            True             Cloudy               600
#         Silt       Rice     True             False            Cloudy               600
# West    Clay       Cotton   False            True             Rainy                600
# South   Chalky     Maize    False            False            Rainy                600
# East    Sandy      Barley   True             True             Rainy                600
#                    Cotton   False            False            Rainy                600
# North   Peaty      Maize    True             False            Sunny                600
# East    Sandy      Maize    True             False            Cloudy               600
#         Chalky     Soybean  False            True             Cloudy               600
#         Clay       Wheat    False            False            Sunny                600
#         Silt       Cotton   True             False            Sunny                600
# North   Clay       Cotton   True             False            Rainy                600
# West    Peaty      Maize    False            True             Rainy                600
# South   Silt       Rice     True             True             Sunny                600
#         Loam       Soybean  False            False            Cloudy               600
# West    Sandy      Soybean  True             True             Rainy                600
# North   Chalky     Wheat    False            False            Sunny                600
# West    Chalky     Barley   False            False            Cloudy               600
# North   Sandy      Cotton   False            False            Cloudy               600
#         Clay       Maize    True             False            Sunny                600
# West    Silt       Barley   True             False            Rainy                600
#         Loam       Wheat    False            True             Rainy                600
# East    Peaty      Maize    False            True             Cloudy               599
# West    Silt       Rice     True             False            Sunny                599
# South   Sandy      Wheat    True             False            Sunny                599
# West    Peaty      Cotton   False            True             Rainy                599
# North   Silt       Rice     True             False            Rainy                599
# East    Loam       Cotton   True             True             Rainy                599
# North   Clay       Wheat    False            False            Cloudy               599
# East    Peaty      Maize    False            True             Sunny                599
# West    Silt       Wheat    True             True             Rainy                599
#         Clay       Cotton   True             False            Sunny                599
#         Silt       Wheat    True             False            Cloudy               599
# North   Peaty      Wheat    True             True             Cloudy               599
# South   Chalky     Maize    True             False            Rainy                599
# East    Sandy      Barley   False            True             Rainy                599
#         Peaty      Barley   True             False            Rainy                599
# North   Loam       Barley   True             True             Cloudy               599
# South   Chalky     Maize    True             True             Sunny                599
# East    Sandy      Wheat    True             False            Rainy                599
# North   Sandy      Barley   False            True             Sunny                599
# South   Sandy      Maize    False            False            Rainy                599
# East    Clay       Cotton   False            False            Cloudy               599
# South   Chalky     Cotton   False            False            Sunny                599
# East    Sandy      Cotton   True             True             Rainy                599
# West    Chalky     Maize    True             False            Sunny                599
# North   Chalky     Rice     False            False            Sunny                598
# West    Chalky     Rice     False            True             Cloudy               598
# South   Clay       Barley   False            True             Cloudy               598
# East    Sandy      Rice     True             False            Sunny                598
# West    Silt       Rice     False            False            Rainy                598
#         Chalky     Maize    True             True             Sunny                598
#                    Cotton   True             False            Cloudy               598
#                    Maize    False            True             Cloudy               598
# East    Loam       Soybean  True             False            Rainy                598
# North   Chalky     Cotton   False            True             Rainy                598
# South   Silt       Cotton   False            True             Rainy                598
# North   Silt       Rice     True             True             Cloudy               598
# South   Silt       Rice     True             True             Rainy                598
# West    Sandy      Maize    True             True             Rainy                598
# North   Loam       Rice     False            False            Sunny                598
# West    Clay       Soybean  True             False            Cloudy               598
# North   Clay       Barley   True             False            Rainy                598
# West    Sandy      Maize    False            True             Rainy                598
# North   Chalky     Soybean  False            True             Sunny                598
# West    Sandy      Barley   False            False            Rainy                598
# South   Sandy      Cotton   True             True             Sunny                597
#         Chalky     Barley   True             True             Sunny                597
#         Loam       Soybean  True             False            Rainy                597
# East    Loam       Wheat    False            True             Sunny                597
#         Sandy      Maize    True             True             Sunny                597
# West    Sandy      Wheat    False            True             Rainy                597
#         Chalky     Barley   False            True             Cloudy               597
# East    Loam       Soybean  True             True             Cloudy               597
# South   Sandy      Wheat    False            False            Rainy                597
#         Clay       Rice     True             False            Rainy                597
#         Silt       Rice     False            False            Sunny                597
# East    Sandy      Wheat    True             True             Cloudy               597
#         Clay       Maize    False            False            Rainy                597
#         Silt       Soybean  True             False            Rainy                597
# North   Sandy      Wheat    True             False            Rainy                597
#         Loam       Wheat    True             True             Rainy                597
# West    Peaty      Soybean  False            False            Cloudy               597
# South   Chalky     Barley   False            True             Rainy                597
# East    Clay       Barley   False            False            Rainy                596
# South   Clay       Rice     True             True             Rainy                596
#         Sandy      Cotton   True             False            Sunny                596
#         Chalky     Soybean  True             True             Cloudy               596
#         Clay       Wheat    True             True             Rainy                596
#         Peaty      Wheat    False            False            Rainy                596
# East    Clay       Barley   False            False            Cloudy               596
# North   Loam       Wheat    True             True             Sunny                596
#         Sandy      Maize    False            False            Rainy                596
#         Peaty      Soybean  False            True             Cloudy               596
# West    Clay       Rice     True             True             Cloudy               596
# North   Chalky     Cotton   False            False            Rainy                596
# South   Peaty      Soybean  False            False            Rainy                596
# North   Chalky     Rice     True             False            Sunny                596
# South   Sandy      Barley   True             True             Sunny                596
# East    Sandy      Wheat    True             False            Sunny                596
#         Silt       Cotton   True             False            Rainy                596
# South   Clay       Wheat    False            True             Cloudy               596
#         Peaty      Maize    True             False            Rainy                596
# North   Loam       Rice     True             False            Sunny                596
# West    Sandy      Maize    False            False            Rainy                596
# North   Sandy      Rice     False            True             Rainy                596
#                    Wheat    False            False            Rainy                596
# West    Sandy      Cotton   False            True             Sunny                596
# South   Chalky     Rice     True             False            Sunny                596
# East    Clay       Wheat    True             True             Cloudy               596
#         Peaty      Rice     True             False            Rainy                596
# North   Silt       Wheat    True             True             Cloudy               596
# West    Loam       Barley   False            True             Rainy                596
# East    Silt       Wheat    False            False            Cloudy               596
# North   Sandy      Maize    True             True             Cloudy               596
# West    Silt       Wheat    False            True             Rainy                596
#         Peaty      Cotton   False            False            Rainy                596
#         Chalky     Rice     False            True             Sunny                595
# South   Sandy      Rice     True             True             Sunny                595
#         Clay       Barley   True             True             Sunny                595
# East    Silt       Barley   False            False            Sunny                595
# North   Sandy      Barley   True             False            Sunny                595
# East    Sandy      Soybean  False            False            Cloudy               595
#         Peaty      Maize    False            False            Cloudy               595
# South   Loam       Maize    False            False            Sunny                595
# East    Silt       Maize    True             True             Rainy                595
#         Sandy      Soybean  False            False            Sunny                595
#         Chalky     Maize    True             True             Rainy                595
# West    Sandy      Maize    False            False            Cloudy               595
# South   Peaty      Soybean  True             True             Sunny                595
#         Clay       Barley   False            True             Rainy                595
# East    Chalky     Cotton   True             False            Cloudy               595
# South   Loam       Soybean  True             True             Cloudy               595
#         Sandy      Wheat    True             False            Cloudy               595
# West    Peaty      Wheat    False            False            Sunny                595
# North   Chalky     Maize    False            False            Rainy                595
# East    Chalky     Soybean  False            True             Sunny                595
# South   Sandy      Cotton   True             False            Rainy                595
#         Peaty      Maize    False            True             Rainy                595
#                                                               Sunny                595
# West    Sandy      Rice     True             False            Sunny                595
# North   Clay       Soybean  True             False            Sunny                595
# East    Clay       Soybean  True             True             Rainy                594
# West    Clay       Wheat    True             False            Sunny                594
#         Chalky     Soybean  True             False            Sunny                594
# East    Clay       Cotton   True             True             Cloudy               594
# North   Peaty      Rice     False            False            Rainy                594
# West    Peaty      Cotton   False            True             Cloudy               594
#         Silt       Maize    False            False            Sunny                594
# South   Sandy      Wheat    False            False            Sunny                594
# North   Chalky     Barley   False            True             Sunny                594
# East    Sandy      Rice     True             True             Sunny                594
# North   Silt       Cotton   True             False            Rainy                594
# West    Peaty      Cotton   True             False            Cloudy               594
#         Chalky     Wheat    True             False            Rainy                594
# East    Silt       Cotton   False            False            Sunny                594
#         Chalky     Wheat    True             True             Sunny                594
# West    Loam       Maize    True             True             Rainy                594
# North   Clay       Cotton   False            False            Rainy                594
# East    Sandy      Wheat    False            True             Sunny                594
# North   Peaty      Wheat    False            True             Cloudy               594
# South   Sandy      Rice     False            False            Cloudy               594
#                    Maize    True             True             Rainy                594
# East    Sandy      Cotton   False            False            Cloudy               594
# South   Sandy      Rice     False            False            Sunny                594
# West    Chalky     Cotton   True             True             Cloudy               594
# East    Silt       Soybean  False            False            Rainy                594
#         Loam       Rice     True             False            Cloudy               594
# North   Silt       Barley   False            True             Cloudy               594
# South   Chalky     Wheat    False            True             Cloudy               594
# East    Silt       Barley   False            True             Rainy                594
# West    Chalky     Maize    False            False            Cloudy               594
# South   Sandy      Wheat    False            True             Sunny                593
# West    Peaty      Barley   True             False            Rainy                593
# South   Clay       Soybean  True             True             Sunny                593
# North   Peaty      Cotton   False            False            Sunny                593
# East    Sandy      Cotton   True             False            Rainy                593
# West    Peaty      Maize    True             True             Sunny                593
# North   Peaty      Rice     False            True             Cloudy               593
# South   Chalky     Cotton   True             True             Rainy                593
# North   Clay       Rice     False            True             Rainy                593
# East    Silt       Barley   True             True             Sunny                593
# North   Peaty      Wheat    False            False            Rainy                593
# South   Sandy      Cotton   True             True             Rainy                593
# West    Clay       Barley   False            False            Sunny                593
# South   Clay       Maize    True             False            Sunny                593
# East    Sandy      Wheat    False            True             Rainy                593
#         Clay       Wheat    True             False            Sunny                593
# North   Sandy      Rice     True             True             Sunny                593
#         Silt       Rice     True             True             Rainy                592
# East    Clay       Cotton   False            True             Sunny                592
# North   Sandy      Rice     False            False            Sunny                592
#         Chalky     Maize    True             True             Sunny                592
#         Loam       Wheat    False            False            Rainy                592
# West    Clay       Maize    False            False            Cloudy               592
# East    Silt       Maize    True             True             Sunny                592
# North   Sandy      Maize    False            True             Sunny                592
# East    Clay       Rice     True             True             Sunny                592
# South   Chalky     Cotton   False            True             Sunny                592
# East    Clay       Soybean  False            True             Rainy                592
# North   Chalky     Wheat    False            False            Cloudy               592
# South   Loam       Barley   False            False            Sunny                592
# North   Loam       Maize    True             True             Cloudy               592
#         Sandy      Cotton   True             False            Sunny                592
#                    Soybean  False            True             Rainy                592
# South   Silt       Barley   False            False            Cloudy               592
# West    Peaty      Rice     True             False            Sunny                592
# East    Peaty      Barley   True             False            Sunny                592
# South   Loam       Rice     True             True             Cloudy               592
# East    Sandy      Barley   True             False            Cloudy               592
# West    Loam       Cotton   True             True             Cloudy               592
# East    Peaty      Maize    True             True             Rainy                592
#         Chalky     Cotton   False            False            Rainy                592
# South   Sandy      Barley   True             False            Sunny                592
# West    Sandy      Wheat    True             True             Sunny                592
# North   Clay       Rice     False            True             Sunny                592
# West    Silt       Wheat    True             False            Sunny                592
# East    Peaty      Barley   False            False            Cloudy               592
# West    Loam       Maize    True             False            Sunny                592
# North   Loam       Barley   False            True             Cloudy               592
# East    Chalky     Rice     False            False            Sunny                592
# South   Silt       Wheat    True             False            Cloudy               591
# North   Silt       Cotton   False            True             Cloudy               591
# East    Silt       Barley   False            False            Rainy                591
#         Loam       Rice     True             False            Sunny                591
#         Silt       Barley   True             False            Sunny                591
# West    Loam       Rice     True             True             Cloudy               591
# North   Clay       Cotton   True             True             Sunny                591
# East    Loam       Maize    True             True             Sunny                591
# West    Sandy      Soybean  False            True             Cloudy               591
# East    Clay       Cotton   False            True             Rainy                591
# South   Sandy      Rice     True             False            Rainy                591
#                    Maize    False            True             Cloudy               591
#         Loam       Wheat    False            True             Cloudy               591
# West    Silt       Maize    False            False            Rainy                591
# East    Clay       Wheat    True             False            Cloudy               591
# West    Peaty      Rice     True             True             Rainy                591
# East    Silt       Soybean  False            True             Cloudy               591
# South   Silt       Barley   True             False            Sunny                591
#                             False            False            Rainy                591
# North   Peaty      Cotton   True             True             Cloudy               591
#         Loam       Soybean  False            False            Cloudy               591
# East    Peaty      Barley   True             True             Rainy                591
# ...
# East    Chalky     Rice     True             True             Rainy                548
#         Peaty      Wheat    False            True             Rainy                548
# South   Loam       Soybean  False            True             Rainy                548
# East    Chalky     Barley   True             False            Rainy                548
#                    Soybean  False            True             Rainy                548
#         Loam       Wheat    True             False            Rainy                548
#         Clay       Wheat    False            True             Sunny                548
#         Sandy      Barley   True             False            Rainy                548
#         Loam       Rice     True             False            Rainy                548
# North   Sandy      Maize    False            False            Cloudy               548
# East    Silt       Cotton   True             True             Cloudy               548
# South   Sandy      Maize    True             True             Sunny                548
#         Chalky     Rice     True             True             Rainy                548
# North   Peaty      Soybean  True             True             Rainy                548
#         Loam       Maize    False            False            Sunny                548
# East    Loam       Maize    False            False            Rainy                547
# North   Peaty      Soybean  False            False            Rainy                547
# East    Clay       Soybean  True             False            Rainy                547
# North   Clay       Wheat    False            False            Rainy                547
# South   Chalky     Soybean  False            True             Rainy                547
# East    Peaty      Maize    True             True             Cloudy               547
# West    Sandy      Rice     False            False            Cloudy               547
# North   Sandy      Rice     False            True             Cloudy               547
# East    Silt       Wheat    False            True             Sunny                547
# West    Loam       Maize    False            False            Sunny                547
# East    Peaty      Rice     False            True             Cloudy               547
#                    Wheat    True             True             Rainy                547
#         Loam       Cotton   False            False            Cloudy               547
# West    Clay       Cotton   False            True             Cloudy               546
# North   Loam       Wheat    False            False            Cloudy               546
# West    Sandy      Rice     True             True             Sunny                546
# South   Peaty      Rice     True             True             Rainy                546
# North   Peaty      Cotton   True             False            Cloudy               546
#                                                               Rainy                546
# West    Chalky     Soybean  False            True             Rainy                546
# South   Peaty      Rice     False            False            Rainy                546
# East    Sandy      Cotton   False            True             Rainy                546
#                    Rice     True             True             Rainy                546
# West    Chalky     Rice     False            False            Sunny                546
#         Sandy      Wheat    False            False            Rainy                546
# East    Chalky     Barley   False            False            Sunny                546
# North   Sandy      Maize    False            False            Sunny                546
# West    Clay       Rice     True             False            Cloudy               546
#         Loam       Barley   False            False            Sunny                546
# South   Sandy      Maize    False            True             Sunny                545
# West    Chalky     Wheat    False            True             Sunny                545
# South   Sandy      Barley   False            False            Sunny                545
#         Silt       Maize    True             False            Cloudy               545
# East    Chalky     Wheat    False            False            Rainy                545
# South   Silt       Barley   True             False            Cloudy               545
# North   Loam       Cotton   False            True             Sunny                545
# East    Silt       Wheat    False            True             Cloudy               544
# West    Sandy      Maize    True             False            Sunny                544
#         Peaty      Soybean  True             False            Cloudy               544
# South   Silt       Wheat    False            False            Rainy                544
# North   Peaty      Soybean  False            True             Rainy                544
# East    Loam       Barley   False            False            Cloudy               544
# North   Silt       Rice     False            True             Sunny                544
#         Sandy      Rice     True             False            Sunny                544
# West    Peaty      Barley   False            True             Cloudy               544
# East    Silt       Wheat    True             False            Cloudy               544
# South   Chalky     Cotton   True             False            Sunny                544
# West    Loam       Maize    False            True             Sunny                544
#         Peaty      Wheat    True             False            Sunny                544
# South   Clay       Maize    False            False            Cloudy               544
# West    Loam       Rice     False            False            Cloudy               544
# South   Sandy      Cotton   False            True             Rainy                544
#         Peaty      Maize    True             True             Sunny                543
#         Sandy      Barley   True             False            Cloudy               543
# West    Clay       Barley   True             False            Rainy                543
# East    Peaty      Soybean  True             False            Sunny                543
# West    Loam       Wheat    False            False            Rainy                543
# East    Silt       Barley   True             True             Cloudy               543
#         Clay       Maize    False            True             Rainy                543
# South   Clay       Cotton   False            False            Cloudy               543
#         Sandy      Soybean  True             False            Rainy                543
# North   Chalky     Soybean  True             False            Rainy                543
#                    Wheat    True             False            Rainy                543
# South   Sandy      Barley   False            True             Cloudy               542
# West    Peaty      Soybean  True             False            Sunny                542
# East    Sandy      Rice     False            True             Cloudy               542
# North   Silt       Cotton   False            False            Cloudy               542
# South   Silt       Cotton   False            False            Sunny                542
# West    Clay       Wheat    True             True             Rainy                542
#         Chalky     Wheat    True             True             Cloudy               542
# North   Chalky     Cotton   True             False            Sunny                542
#         Sandy      Soybean  True             True             Sunny                542
# East    Chalky     Wheat    False            True             Sunny                542
# West    Peaty      Cotton   True             True             Sunny                541
# South   Clay       Cotton   True             True             Sunny                541
# West    Chalky     Soybean  False            False            Sunny                541
# North   Loam       Soybean  True             False            Rainy                541
# East    Clay       Wheat    False            True             Cloudy               541
# West    Silt       Maize    False            False            Cloudy               541
#         Clay       Wheat    False            False            Rainy                541
#         Peaty      Soybean  False            True             Cloudy               541
# North   Clay       Barley   False            True             Rainy                541
#         Silt       Maize    True             False            Cloudy               540
#                    Soybean  True             True             Rainy                540
#                             False            False            Cloudy               540
# West    Sandy      Barley   False            False            Cloudy               540
# South   Silt       Cotton   True             True             Sunny                540
# North   Silt       Cotton   False            True             Rainy                540
# East    Peaty      Cotton   True             False            Cloudy               540
# South   Clay       Cotton   True             False            Cloudy               540
# West    Chalky     Maize    True             False            Rainy                539
#                    Soybean  False            False            Cloudy               539
#         Loam       Wheat    False            True             Sunny                539
#         Peaty      Cotton   True             False            Rainy                539
# South   Silt       Rice     True             False            Cloudy               539
# East    Sandy      Soybean  True             True             Sunny                539
# West    Clay       Soybean  True             False            Rainy                539
# North   Peaty      Barley   False            False            Sunny                538
# West    Silt       Maize    False            True             Sunny                538
# North   Chalky     Wheat    False            False            Rainy                538
#         Sandy      Cotton   False            True             Sunny                538
#         Clay       Soybean  False            False            Rainy                538
# South   Clay       Cotton   True             True             Cloudy               538
# East    Peaty      Maize    True             False            Sunny                538
# North   Clay       Barley   True             True             Rainy                538
#         Sandy      Maize    False            True             Cloudy               538
# West    Chalky     Soybean  False            True             Sunny                538
# East    Loam       Soybean  False            False            Sunny                538
# South   Clay       Barley   True             False            Rainy                537
# West    Sandy      Rice     False            True             Sunny                537
# East    Peaty      Soybean  True             False            Cloudy               537
# South   Chalky     Rice     True             True             Cloudy               537
# East    Loam       Maize    False            False            Sunny                536
# South   Clay       Rice     True             True             Cloudy               536
# East    Peaty      Wheat    False            False            Sunny                536
# South   Sandy      Rice     False            True             Sunny                536
# East    Loam       Cotton   False            True             Rainy                536
#         Peaty      Cotton   True             True             Sunny                536
#         Silt       Soybean  False            True             Sunny                535
# North   Sandy      Barley   True             True             Cloudy               535
#         Chalky     Maize    True             False            Sunny                535
#         Sandy      Wheat    True             True             Cloudy               534
# West    Loam       Rice     True             True             Sunny                534
# North   Chalky     Maize    True             False            Rainy                534
# East    Chalky     Cotton   True             True             Rainy                534
# North   Chalky     Maize    False            True             Cloudy               533
# South   Silt       Maize    True             True             Rainy                533
# East    Clay       Maize    True             True             Rainy                533
#                                              False            Cloudy               533
# North   Chalky     Cotton   False            True             Cloudy               532
#         Silt       Barley   False            False            Rainy                532
#         Clay       Barley   False            True             Sunny                532
# West    Chalky     Rice     True             False            Cloudy               531
#         Sandy      Wheat    True             False            Rainy                531
#         Chalky     Cotton   False            False            Sunny                530
#         Silt       Barley   True             True             Rainy                530
# East    Chalky     Maize    True             False            Sunny                530
# West    Silt       Cotton   False            True             Rainy                530
# North   Silt       Cotton   True             True             Cloudy               529
#         Sandy      Barley   False            False            Rainy                528
# East    Silt       Rice     False            True             Sunny                528
#         Peaty      Soybean  False            False            Cloudy               528
#         Sandy      Rice     True             False            Rainy                527
# West    Peaty      Soybean  True             True             Sunny                526
# South   Loam       Maize    True             False            Rainy                526
# North   Clay       Soybean  False            True             Cloudy               525
#         Peaty      Barley   True             True             Sunny                524
# South   Chalky     Wheat    False            True             Rainy                524
# North   Sandy      Soybean  True             False            Rainy                523
# East    Clay       Maize    False            True             Cloudy               522
#         Silt       Cotton   False            True             Rainy                521
#                             True             False            Cloudy               521
# South   Peaty      Maize    False            False            Cloudy               520
# East    Loam       Barley   False            True             Rainy                520
# South   Silt       Wheat    False            False            Cloudy               520
# East    Chalky     Barley   True             False            Sunny                520
# North   Silt       Wheat    False            True             Cloudy               520
# West    Sandy      Soybean  False            False            Sunny                519
#                    Maize    True             False            Rainy                519
#         Silt       Maize    True             False            Rainy                519
# North   Silt       Soybean  True             True             Sunny                518
#         Loam       Maize    True             False            Rainy                518
#         Chalky     Barley   True             False            Cloudy               516
# East    Chalky     Rice     True             True             Cloudy               516
#                    Cotton   False            True             Sunny                510
#         Silt       Cotton   False            False            Cloudy               509
#         Loam       Maize    True             True             Cloudy               508
#         Chalky     Barley   True             False            Cloudy               500
# Name: count, dtype: int64

# %% [markdown]
# #**Key Observations and conclusions** :
#
# ###1. **Irrigation and Fertilizer Synergy for Yield Optimization**:
#
#
# - In cases where **both irrigation and fertilizers are used (e.g., wheat in the South), there may be a higher crop count compared to instances** where one or both are not used. This suggests that the combination of both practices could be essential for optimizing crop yield.
#
#
# ###2. **Regional Dependency on Soil Type for Crop Success**:
#
# - The data shows that **specific crops thrive in certain regions due to soil type.** For example, the North predominantly cultivates maize on silt or loam soil, while the South grows rice on sandy soil. This points to the importance of soil compatibility in regional agricultural practices.
#
#
# ###3. **Weather’s Critical Impact on Agricultural Output**:
#
# - **Sunny weather conditions seem to be associated with higher crop counts (e.g., maize and cotton in the North)**, while crops under cloudy conditions (e.g., rice in the South) may have slightly lower counts. Weather could be a determining factor in both crop selection and yield potential.
#
#
# ###4. **Fertilizer Use is Crop-Specific Rather than Region-Specific**:
#
# -  While regions **differ in soil and crop types, the usage of fertilizer appears to be more strongly linked to the type of crop rather than the region itself.** For example, fertilizer use is common with rice and wheat, regardless of the region, indicating that certain crops demand external nutrients for better yield.
#
#
# ###5. **Water Management Practices Vary Across Regions**:
#
# - In the South, irrigation is used more consistently with crops like rice and wheat, while in the North, irrigation usage appears more selective, possibly due to natural water availability or regional farming practices.**This shows how water management strategies are adapted to local conditions and crop requirements.**
#
#
# These conclusions emphasize the critical role of **environmental factors (soil, weather) and farming practices (irrigation, fertilizer)** in determining agricultural productivity.

# %%
pd.reset_option('display.max_rows')  # Resetting to display 5 records

# %% [markdown]
# ## **Exploring Data As As Hole**

# %% [markdown]
# ##**Comparing 2 numeric data**

# %%
sns.histplot(df['Yield_tons_per_hectare'], bins=20,color="green")
plt.xlabel('Yield_tons_per_hectare')
plt.ylabel('Frequency')
plt.title('Histogram of Yield_tons_per_hectare')
plt.show()

# %% [markdown]
# # **Key Observations:**
#
# ###1. **Distribution:**
#    - The histogram shows a bell-shaped distribution, indicating that the yield (tons per hectare) follows a normal distribution.
#
#
# ###2. **Frequency:**
#
#    - Most yield values are clustered around 4-5 tons per hectare, with a frequency peak of over 100,000.
#
#
# ###3. **Symmetry:**
#
#    - The distribution appears to be symmetrical, with yield values spread evenly on both sides of the mean.
#
#
# ###4. **Range:**
#
#
#    - Yield values range from 0 to 10 tons per hectare, with very few extreme low or high values.
#
#
# ###5. **Tails:**
#
#    - The extremes (below 1 ton and above 9 tons) have very low frequencies, indicating few outliers on either end.

# %% [markdown]
# # **Insights:**
#
# - The **normal distribution** of yield suggests that the data is balanced, with most crops falling in the average yield range (around 4-5 tons).
#
# - The small number of values at the **extreme low and high ends** indicates that unusual yield outcomes (very low or very high) are rare.
#
# - This distribution aligns well with the boxplot observation, where the median yield was around 4.5 tons per hectare, and most data points were concentrated near the center.

# %%
plt.hexbin(df['Rainfall_mm'], df['Yield_tons_per_hectare'], gridsize=20, cmap='Greens')
plt.colorbar(label='Count')  # Add a color bar for reference
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (tons per hectare)')
plt.show()

# %% [markdown]
# #**Key Observations :**
#
# ###1. **Positive Correlation Between Rainfall and Yield:**
#    - Both plots (with and without fertilizer) show a **clear positive correlation** between **rainfall** and **yield**.
#
#    - As rainfall increases, crop yields also tend to increase. This is particularly evident between **400 mm and 900 mm** of rainfall, where yields generally rise.
#
#
# ###2. **Densest Areas Indicate Ideal Rainfall:**
#    - In both plots, the densest concentration of yield values is found at **500 to 700 mm of rainfall**, suggesting that this range of rainfall is the **most favorable** for maximizing crop yield.
#
#
#    - With fertilizer, yields between **5 and 7 tons** dominate this range, while without fertilizer, the peak yield remains slightly lower, around **4 to 6 tons/hectare**.
#
# ###3. **Yield at Extreme Rainfall Levels:**
#
#    - For **rainfall levels below 300 mm**, yields are consistently lower, typically below **4 tons/hectare**, in both plots. This suggests that **insufficient rainfall** significantly limits crop yield.
#
#
#    - At the higher end (above **900 mm** of rainfall), yields also tend to taper off, indicating that **excessive rainfall** may negatively impact crop productivity, even with the use of fertilizer.
#
#
#
# #**Insights:**
#
# - **Rainfall is a Strong Predictor of Yield:** A clear positive relationship is evident between rainfall and yield in both conditions (with and without fertilizer).
#
#
# - **Fertilizer Enhances Yield:** The use of fertilizer boosts the yield across all rainfall levels, with the greatest benefit seen between **500-900 mm** of rainfall, where yields of **6-8 tons/hectare** are most common.
#
#
# - **Optimal Rainfall Range for High Yields:** The ideal rainfall for maximum crop productivity lies between **500 mm to 700 mm**, beyond which yields tend to plateau or decline.
#
#
# - **Low and High Rainfall Affect Yield Negatively:** Insufficient rainfall (<300 mm) leads to low yields, and excessive rainfall (>900 mm) also reduces yield, likely due to waterlogging or nutrient leaching.

# %%
plt.hexbin(df['Temperature_Celsius'], df['Yield_tons_per_hectare'],gridsize=20, cmap='Greens')
plt.xlabel('Temperature (Celsius)')
plt.ylabel('Yield (tons per hectare)')
plt.title('Hexbin Plot of Temperature vs. Yield')
plt.colorbar()
plt.show()

# %% [markdown]
# #**Key Observations :**
#
# ###1. **Yield Range Across Temperatures:**
#
#   - The plot shows a relatively **consistent yield range** (2-8 tons/hectare) across the entire temperature spectrum from 15°C to 40°C, suggesting that temperature alone may not be the most dominant factor influencing yield within this range.
#
#   - The **densest region** (darkest green) is centered between **20°C and 30°C** with yields clustering around **4 to 6 tons/hectare**, indicating that this temperature range might be the most optimal for crop growth.
#
#
# ###2. **Optimal Temperature for Maximum Yield:**
#
#    - The plot suggests that yields remain relatively high between **20°C to 30°C**, where the most data points are concentrated. Crops tend to achieve their **best yield** in this moderate temperature zone, showing that this range might provide ideal growing conditions.
#
#
# ###3. **Yield Decline at Extreme Temperatures:**
#    - Outside the optimal range (above 35°C and below 20°C), there is **less dense clustering**, and yields appear to decline slightly, especially at **higher temperatures** (>35°C). This could indicate potential stress on crops in extreme heat conditions, where fewer data points show high yield.
#    - Yields remain within the 2–6 tons range at extreme temperatures, but with **lower frequency**, suggesting that **extreme cold or heat limits productivity**.
#
#
# ###4. **Temperature and Yield Stability:**
#    - The relatively flat and consistent pattern in the hexbin distribution indicates that while temperature affects yield, it might not be the most critical limiting factor within this range. Other factors such as rainfall, soil type, and fertilizer may play a stronger role in determining yield outcomes.
#
#
# #**Insights :**
#
#
# - **Moderate Temperatures (20-30°C) Support Optimal Yield:** Crops achieve the highest and most consistent yields in this temperature range.
#
#
# - **Temperature Extremes Reduce Yield Density:** As temperature rises above 35°C or falls below 20°C, yield densities decrease, suggesting potential limitations on crop productivity at these extremes.
#
#
# - **Temperature Alone Doesn’t Dictate Yield:** The broad and even distribution of yields across temperatures suggests that temperature is one factor among many influencing crop yield, and its impact may be more pronounced when combined with other variables like water availability and soil health.

# %%
plt.hexbin(df['Days_to_Harvest'], df['Yield_tons_per_hectare'],gridsize=20, cmap='Greens')
plt.xlabel('Days_to_Harvest')
plt.ylabel('Yield (tons per hectare)')
plt.title('Hexbin Plot of Days_to_Harvest vs. Yield')
plt.colorbar()
plt.show()

# %% [markdown]
# #**Key Observations :**
#
# ###1. **Moderate Positive Correlation:**
#
#    - The hexbin plot shows a **moderate positive correlation** between **days to harvest** and **yield**.
#
#    - As the number of days to harvest increases, crop yield tends to rise, especially within the range of **60 to 120 days**. However, the relationship is not as strong as seen with other factors like rainfall.
#
# ###2. **Densest Area Between 80 and 120 Days:**
#
#
#    - The **dark green** hexagons, representing the densest area, are concentrated between **80 and 120 days** to harvest. In this range, yields are consistently **between 4 and 6 tons per hectare**, indicating that this period is the **most productive** for crops in terms of maximizing yield.
#
#
# ###3. **Yields Peak Around 90 to 100 Days:**
#    - The highest yields, ranging from **5 to 8 tons per hectare**, tend to cluster around the **90 to 100 days** mark. This suggests that crops harvested within this timeframe achieve optimal yield performance.
#
#
#
# ###4. **Low Yield with Short Harvest Periods:**
#
#    - For **harvests less than 80 days**, yields tend to remain low, typically below **4 tons per hectare**. This suggests that **short harvest periods** may result in underdeveloped crops and lower productivity.
#
#
#
# #**Insights:**
#
#
# - **Optimal Harvest Period for Maximum Yield:** The ideal range for harvesting crops, based on this dataset, is between **90 and 120 days**, where the highest yields of **5 to 8 tons per hectare** are most common.
#
#
# - **Short Harvest Periods Yield Lower:** Crops harvested in **less than 80 days** tend to produce lower yields, likely due to insufficient growth or maturation.
#
#
#
# - **Longer Harvest Periods Don’t Significantly Increase Yield:** After **120 days**, yields tend to plateau, indicating that prolonging the harvest time may not significantly increase crop productivity.
#
#
#
# - **Balance Between Growth Time and Yield:** Timing the harvest between **80 to 120 days** appears to provide the best balance between crop growth and yield, ensuring crops have adequate time to mature without overextending the harvest period.

# %% [markdown]
# ##**Comparing 2 categorical data**

# %%
import pandas as pd
# Pivot table for Region, Soil_Type, Crop
pivot_table_region_soil_crop = pd.pivot_table(df, values='Yield_tons_per_hectare', index=['Region', 'Soil_Type'], columns=['Crop'], aggfunc='median')

# Display the pivot table
print(pivot_table_region_soil_crop)
# Out:
# Crop                Barley    Cotton     Maize      Rice   Soybean     Wheat
# Region Soil_Type
# East   Chalky     4.682030  4.674352  4.676729  4.622221  4.657004  4.654834
#        Clay       4.669660  4.665083  4.611875  4.657810  4.681504  4.621763
#        Loam       4.651015  4.654012  4.669431  4.636558  4.619080  4.627548
#        Peaty      4.673313  4.616218  4.655207  4.651125  4.712896  4.649550
#        Sandy      4.655713  4.688762  4.578869  4.639872  4.581116  4.684778
#        Silt       4.634922  4.675453  4.632300  4.649913  4.613414  4.654102
# North  Chalky     4.687689  4.648724  4.677288  4.644578  4.654794  4.644884
#        Clay       4.667575  4.608096  4.630855  4.613022  4.678642  4.678618
#        Loam       4.677873  4.602564  4.677962  4.631286  4.660147  4.754163
#        Peaty      4.643154  4.690022  4.648483  4.665311  4.670684  4.663547
#        Sandy      4.717756  4.681908  4.618176  4.678460  4.644004  4.641093
#        Silt       4.640183  4.676434  4.648814  4.666773  4.676232  4.655386
# South  Chalky     4.631439  4.684557  4.652638  4.653972  4.610432  4.675419
#        Clay       4.587021  4.635053  4.653145  4.677844  4.672637  4.579215
#        Loam       4.627255  4.627408  4.673848  4.647238  4.644756  4.666687
#        Peaty      4.678210  4.631190  4.659345  4.674994  4.678879  4.666237
#        Sandy      4.654202  4.597930  4.632936  4.632882  4.651961  4.620695
#        Silt       4.630379  4.673589  4.612175  4.637037  4.646725  4.690356
# West   Chalky     4.637360  4.644316  4.666329  4.703335  4.710070  4.656817
#        Clay       4.678362  4.663667  4.623411  4.649693  4.634870  4.723201
#        Loam       4.601667  4.625880  4.661521  4.637549  4.690615  4.622734
#        Peaty      4.635378  4.644347  4.577862  4.691071  4.620250  4.628444
#        Sandy      4.617932  4.654112  4.647948  4.663218  4.731375  4.638824
#        Silt       4.629333  4.651115  4.648279  4.641536  4.656188  4.645559

# %% [markdown]
# #**Key Observations :**
#
# Based on the pivot table for **Region**, **Soil_Type**, **Crop**, and **Yield Tons per Hectare (median)**, here are key observations and insights:
#
# ###1. **Region-wise Yield Analysis**:
#
#
#    - **North Region** generally shows higher yields for most crops across various soil types, especially for **Barley** and **Cotton**.
#
#
#    - **East and South Regions** show slightly lower median yields compared to the North, particularly for **Soybean** and **Rice**.
#
#
#    - **West Region** has more consistent yields across all crops, but the yields for crops like **Maize** and **Wheat** tend to be slightly lower compared to the North.
#
# ###2. **Soil Type Influence**:
#
#
#    - **Loam Soil** consistently offers some of the best yields across regions for all crops, showing its suitability for diverse types of agriculture.
#
#
#    - **Peaty Soil** also produces relatively high yields, especially for crops like **Cotton**, **Rice**, and **Wheat**, showing the soil's versatility.
#
#
#    - **Sandy and Chalky Soils** have more variability. Crops like **Barley** and **Cotton** seem to fare better in **Sandy** soil, while **Chalky** soil sees lower yields overall.
#
#
#    - **Silt Soil** generally shows stable but medium-range yields, particularly for **Soybean** and **Rice**.
#
# ###3. **Crop-Specific Insights**:
#
#
#
#    - **Barley**: High yields across most soil types in the **North** and **West** regions, particularly in **Loam** and **Sandy** soils.
#
#
#    - **Cotton**: Performs best in **Loam** and **Peaty** soils, especially in the **North** region.
#
#
#    - **Maize**: High yields in **Sandy** soil in the **East** region, but **Clay** and **Silt** soils in the **West** seem less favorable.
#
#
#    - **Rice**: Shows better yields in **Peaty** and **Loam** soils across the **East** and **South** regions. **Sandy** soil does not support high rice yields.
#
#
#    - **Soybean**: Has consistent but lower yields across most regions and soils, especially in **Chalky** soil.
#
#
#    - **Wheat**: Achieves its best yields in **Loam** and **Peaty** soils, particularly in the **North** and **West** regions.
#
#
#
#
# ###4. **Region and Soil Interaction**:
#
#
#    - The **North** region's combination of **Loam** and **Peaty** soils delivers the highest median yield for most crops.
#
#
#
#    - **East** and **South** regions benefit from **Silt** and **Loam** soils, but crops like **Maize** and **Soybean** may not perform as well as in other regions.
#
#
#    - **West** region yields tend to be slightly lower but more consistent across soil types, indicating stability in agricultural conditions.
#
#
#
# #**Insights**:
#    - **Loam Soil** stands out as the most productive for a wide range of crops, particularly in the **North** and **West** regions. This makes it a prime candidate for crop rotation strategies.
#
#
#
#    - **Peaty Soil** is highly beneficial for crops like **Rice**, **Cotton**, and **Wheat**, while **Sandy Soil** may be better suited for **Barley** and **Cotton** in specific regions.
#
#
#    - Regions like the **North** demonstrate better overall yields, indicating favorable agricultural conditions, which might include better climate, rainfall, or resource management (e.g., irrigation, fertilizer use).
#
#
#    - **Irrigation and Fertilizer** should be optimized based on soil type and crop to ensure maximum yield, as not all crops respond equally to these inputs.
#
#
#
# These insights provide a foundation for strategic decisions regarding **crop planning**, **soil management**, and **regional agricultural policies**. They can also guide **resource allocation** such as water and fertilizer for improving crop yields across different regions and soil types.

# %%
# Pivot table for Fertilizer_Used, Irrigation_Used, Crop
pivot_table_Fertilizer_Used_soil_crop = pd.pivot_table(df, values='Days_to_Harvest', index=['Fertilizer_Used', 'Irrigation_Used'], columns=['Crop'], aggfunc='median')

# Display the pivot table
print(pivot_table_Fertilizer_Used_soil_crop)
# Out:
# Crop                             Barley  Cotton  Maize   Rice  Soybean  Wheat
# Fertilizer_Used Irrigation_Used
# False           False             104.0   104.0  105.0  104.0    105.0  104.0
#                 True              104.0   104.0  105.0  105.0    104.0  105.0
# True            False             104.0   105.0  105.0  105.0    105.0  104.0
#                 True              104.0   105.0  104.0  104.0    104.0  104.0

# %% [markdown]
# #**Key Observations :**
#
# Based on the pivot table for **Crop**, **Fertilizer Used**, **Irrigation Used**, and **Days to Harvest (median)**, here are the key observations and insights:
#
#
#
# ###1. **Effect of Fertilizer on Days to Harvest**:
#
#
#
#    - For all crops, using **fertilizer** generally reduces the **days to harvest** compared to cases where no fertilizer is used.
#
#
#    - **Crops like Barley, Cotton, and Maize** exhibit a noticeable reduction in harvest time when fertilizer is applied. For example, the days to harvest for **Barley** drops significantly when fertilizer is used.
#
#
#    - The difference in days to harvest with and without fertilizer is more pronounced for crops like **Rice** and **Soybean**, which may indicate these crops are more responsive to the use of fertilizers.
#
#
#    - **Wheat** shows a slight but consistent reduction in harvest days with fertilizer application, which could imply a stable effect of fertilizer on wheat growth cycles.
#
#
#
# ###2. **Impact of Irrigation on Days to Harvest**:
#
#
#    - **Irrigation** consistently helps reduce the days to harvest for most crops, but its impact varies depending on the crop type.
#
#
#
#    - For crops like **Maize** and **Soybean**, irrigation reduces harvest time significantly when fertilizer is also used. This indicates a synergy between **irrigation** and **fertilizer** in accelerating crop maturity.
#
#
#    - Crops like **Barley** and **Wheat** show a more modest reduction in days to harvest when irrigated, regardless of whether fertilizer is used.
#
#
#    - **Rice**, which is a water-intensive crop, shows significant reductions in days to harvest with irrigation, particularly when fertilizer is also applied.
#
# ###3. **Combined Effect of Fertilizer and Irrigation**:
#
#
#    - The combination of **fertilizer** and **irrigation** shows the maximum reduction in **days to harvest** across all crops, indicating that these two factors together are crucial for optimizing crop maturity.
#
#
#    - For **crops like Cotton and Rice**, where both fertilizer and irrigation are applied, the median days to harvest are much lower than when these inputs are used separately.
#
#
#    - The effect of combined fertilizer and irrigation is particularly strong in **Maize**, where harvest time is reduced significantly, making it one of the most responsive crops to both inputs.
#
# ### 4. **Crop-Specific Insights**:
#
#
#    - **Barley**: Shows reduced days to harvest with either fertilizer or irrigation, but the combination results in the most significant improvement.
#
#
#    - **Cotton**: Strongly responds to both fertilizer and irrigation, with a drastic reduction in harvest time when both are used.
#
#
#    - **Maize**: Exhibits the highest reduction in days to harvest with both fertilizer and irrigation. Without either, it has one of the longest growth cycles.
#
#
#    - **Rice**: Requires both fertilizer and irrigation for the most efficient growth. Irrigation, in particular, plays a large role in reducing its growth period.
#
#
#    - **Soybean**: Similar to rice, **soybean** shows a noticeable reduction in harvest days when both fertilizer and irrigation are used.
#
#
#    - **Wheat**: Displays less variability across different conditions, but the combination of inputs still results in faster harvest times.
#
# ### 5. **Insights on Resource Optimization**:
#    - **Fertilizer Usage**: For crops like **Maize**, **Rice**, and **Soybean**, fertilizer has a stronger impact on reducing the harvest time. This implies that **prioritizing fertilizer for these crops** can yield faster returns.
#
#
#    - **Irrigation Prioritization**: For **Rice**, **Cotton**, and **Soybean**, irrigation significantly reduces the harvest period, especially when combined with fertilizer. Optimizing irrigation systems for these crops can greatly improve harvest timelines.
#
#
#    - **Combined Strategy**: Implementing both **fertilizer and irrigation** for crops like **Cotton**, **Maize**, and **Rice** can lead to the most efficient use of agricultural resources, maximizing crop output while reducing time to harvest.
#
# #**Insights :**
#    - The **combined use of fertilizer and irrigation** is crucial for most crops in reducing the number of days to harvest, which can help optimize farming cycles and increase the number of growing seasons per year.
#
#
#    - For **crops like Maize and Cotton**, which are highly responsive to these inputs, farms can expect significant efficiency gains by using both inputs together.
#
#
#    - **Rice and Soybean** are also highly dependent on both fertilizer and irrigation, and for farms specializing in these crops, investment in both resources will likely yield higher and faster returns.
#
#
#    - For **Wheat and Barley**, while the effects of fertilizer and irrigation are present, they are less dramatic, suggesting that these crops may be less input-intensive for farmers looking for a more stable crop with fewer resource needs.
#
#
#
# These insights can help farmers and agricultural planners decide where to **allocate fertilizer and irrigation resources** most efficiently, enabling faster harvests and potentially multiple cropping seasons per year.

# %% [markdown]
# ##**Comparing numeric and categorical data**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))
sns.barplot(x='Crop', y='Yield_tons_per_hectare', hue='Irrigation_Used', data=df,palette=['mediumseagreen','green'])
plt.title('Crop Yield by Irrigation Usage')
plt.xlabel('Crop Type')
plt.ylabel('Yield (tons per hectare)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# #**Key Observations:**
#
# ###1. **Irrigation Impact on Yield**:
#
#
#    - Across all crop types, yields are higher when irrigation is used (`True`) compared to when it is not (`False`). This highlights the positive impact of irrigation on crop production.
#
#
#
# ###2. **Yield Variation by Crop Type**:
#
#
#    - **Rice, Barley, Wheat, and Maize** show the most significant difference in yield between irrigated and non-irrigated conditions.
#
#
#    - **Cotton** and **Soybean** also show yield improvement with irrigation, but the difference appears to be slightly smaller compared to the other crops.
#
# ###3. **Highest Yield Crop (Irrigated)**:
#
#
#    - **Rice** and **Maize** have the highest yields under irrigation conditions, both exceeding 5 tons per hectare.
#
# ###4. **Lowest Yield Crop (Non-Irrigated)**:
#    - **Barley** and **Wheat** have the lowest yields without irrigation, falling below 4 tons per hectare.
#
#
# ###5. **Consistent Performance**:
#    - Regardless of irrigation usage, crop types such as **Rice** and **Maize** consistently perform better in terms of yield compared to others.
#
#
# #**Insights :**
#
# ###1. **Irrigation as a Key Productivity Driver**:
#    - The clear trend of higher yields with irrigation suggests that investment in irrigation infrastructure could substantially improve agricultural productivity, especially for crops like Rice and Maize.
#
# ###2. **Prioritizing Irrigation for Certain Crops**:
#    - Policy makers and farmers should prioritize irrigation for crops with the largest yield differential between irrigated and non-irrigated conditions, such as Wheat, Barley, and Maize.
#
# ###3. **Resource Allocation**:
#
#    - This data can help allocate water resources more efficiently, focusing on crops that see the highest yield improvements with irrigation, ensuring optimal usage of limited water supplies.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='Yield_tons_per_hectare', hue='Fertilizer_Used', data=df,palette=['mediumseagreen','green'])
plt.title('Yield_tons_per_hectare by Region and Fertilizer')
plt.show()

# %% [markdown]
# #**Key Observations:**
#
# ###1. **Weather Condition: Cloudy (Left Box Plot):**
#    - When fertilizer is not used, the median yield is lower, around 4 tons/hectare.
#
#    - With fertilizer use, the yield improves, and the median rises to around 6 tons/hectare.
#
#    - There are outliers with extreme yield values (~9 tons/hectare) in both fertilizer-used and non-fertilizer categories.
#
# ###2. **Weather Condition: Rainy (Middle Box Plot):**
#    - For both fertilizer use and non-use, yields are fairly similar, but the median yield is slightly higher (approximately 6 tons/hectare) when fertilizer is used.
#
#    - A wider range of yields is observed when no fertilizer is used, with outliers present for non-use cases around 1 ton/hectare.
#
# ###3. **Weather Condition: Sunny (Right Box Plot):**
#    - In sunny weather, fertilizer usage causes a significant increase in median yield, about 6 tons/hectare compared to 4.5 tons/hectare without fertilizer.
#
#    - A notable outlier (~1 ton/hectare) exists when fertilizer is used in sunny weather.
#
# #**Insights:**
# - **Fertilizer use has a consistent positive impact on yield** across all weather conditions.
#
# - **Cloudy and sunny weather show stronger responses to fertilizer,** with a higher median yield when fertilizer is applied.
#
# - **Rainy conditions show a smaller difference in yield** between fertilizer use and non-use, implying that rainfall itself may provide significant nutritional support for crops.
#
# - Outliers, especially under sunny and cloudy conditions, suggest variable results in yield even with fertilizer.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame

g = sns.FacetGrid(df, col='Fertilizer_Used', height=4)
g.map(plt.hexbin, 'Days_to_Harvest', 'Yield_tons_per_hectare', gridsize=20, cmap='Greens', edgecolors='none')
g.set_axis_labels('Days_to_Harvest', 'Yield (tons per hectare)')
g.set_titles('Fertilizer Used: {col_name}')
plt.show()

# %% [markdown]
# #**Key Observations:**
#
# ###1. **Without Fertilizer Used:**
#
#
# - There's a broad range of yields across different rainfall levels. The **highest yields are centered around 600 mm of rainfall.**
#
#
# - The **yield variation is quite spread out** across rainfall levels, but generally, there is a pattern where medium to high rainfall (around 400 to 800 mm) **correlates with higher yields.**
#
#
# ###2. **With Fertilizer Used:**
#
# - The use of fertilizer seems to enhance yield significantly across all levels of rainfall, with the **darkest areas indicating the most frequent higher yields spanning a wide range of rainfall,** from approximately 400 to 900 mm.
#
#
# - The plot shows a more pronounced **increase in yield with the increase in rainfall when fertilizer is used,** suggesting that fertilizer could be enhancing the **crop's ability to utilize available water more effectively.**
#
#
#
# #**Insights:**
#
#
#
#
# ###1. **Fertilizer Use Amplifies the Benefits of Rainfall:**
# - The use of fertilizer not only increases the overall yield but also enhances the crop’s ability to take advantage of higher rainfall levels.
#
#
#
# ###2. **Optimizing Both Factors:**
# -  Integrated rainfall and fertilizer management can lead to significant productivity improvements, particularly in areas with moderate to high rainfall.
#
#
#
# ###3. **Yield Limitations Without Fertilizer:**
# - Even with sufficient rainfall, the absence of fertilizer imposes a cap on yield potential, suggesting that water alone cannot maximize agricultural productivity without proper nutrient management.

# %%
import matplotlib.pyplot as plt
# Create a FacetGrid with 'Weather_Condition' as the column
g = sns.FacetGrid(df, col='Weather_Condition', height=4)

# Map a boxplot of 'Yield_tons_per_hectare' vs 'Irrigation_Used' to each facet
g.map(sns.boxplot, 'Irrigation_Used', 'Yield_tons_per_hectare',palette=['mediumseagreen','green'])

# Add axis labels and titles
g.set_axis_labels('Irrigation Used', 'Yield (tons per hectare)')
g.set_titles('Weather Condition: {col_name}')

# Show the plot
plt.show()

# %% [markdown]
# #**Key Observations :**
#
#
#
# ###1. **Cloudy Weather**:
#
#
#    - Irrigation improves yield from around 4 to **6 tons/ha**.
#
#
#    - Yield is more consistent with irrigation, showing fewer variations.
#
#
#
# ###2. **Rainy Weather**:
#
#
#    - Natural rain reduces the irrigation effect slightly, but irrigation still raises median yield from **5 to 6 tons/ha**.
#
#
#    - There's wider variability, as rain introduces natural fluctuations in crop performance.
#
#
#
# ###3. **Sunny Weather**:
#
#
#    - The largest yield improvement happens under sunny conditions, where irrigation increases yield from **4.5 to 6.5 tons/ha**.
#
#
#    - Without irrigation, yields are more unpredictable, making irrigation essential.
#
#
#
#
#
#
# #**Insights:**
#
# - The consistency in yield improvement with irrigation across all weather conditions highlights the importance of irrigation systems for **maintaining high agricultural output, regardless of the weather.**
#
#
# - The larger variability in yields without irrigation, especially in sunny and rainy conditions, suggests that **relying solely on weather (rain) introduces risk,** while irrigation reduces this risk and leads to more predictable outcomes.
#
#
# - In rainy conditions, while irrigation still improves yield, the effect is less dramatic, **implying that natural rainfall can partially replace irrigation in such weather,** although **irrigation provides additional assurance for optimal growth.**
#
#
# Irrigation is most crucial under sunny conditions, where water is scarcer and crops rely heavily on artificial irrigation to meet their water needs and achieve high yields.

# %%
import matplotlib.pyplot as plt
# Create a FacetGrid with Weather_Condition as the column
g = sns.FacetGrid(df, col="Weather_Condition", height=4)

# Map a boxplot of Yield_tons_per_hectare based on Fertilizer_Used onto each facet
g.map(sns.boxplot, "Fertilizer_Used", "Yield_tons_per_hectare",palette=['mediumseagreen','green'])

# Add titles and labels
g.set_axis_labels("Fertilizer Used", "Yield (tons per hectare)")
g.set_titles("Weather Condition: {col_name}")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #**Key Observations:**
#
# ###1. **Weather Condition: Cloudy (Left Box Plot):**
#    - When fertilizer is not used, the median yield is lower, around 4 tons/hectare.
#
#    - With fertilizer use, **the yield improves, and the median rises to around 6 tons/hectare.**
#
#    - There are outliers with extreme yield values (~9 tons/hectare) in both fertilizer-used and non-fertilizer categories.
#
# ###2. **Weather Condition: Rainy (Middle Box Plot):**
#    - For both fertilizer use and non-use, yields are fairly similar, but the median **yield is slightly higher** (approximately 6 tons/hectare) when fertilizer is used.
#
#    - A wider range of yields is observed **when no fertilizer is used, with outliers present for non-use cases around 1 ton/hectare.**
#
# ###3. **Weather Condition: Sunny (Right Box Plot):**
#    - In sunny weather, fertilizer usage causes a significant increase in median yield, about 6 tons/hectare compared to 4.5 tons/hectare without fertilizer.
#
#    - A notable outlier (~1 ton/hectare) exists when fertilizer is used in sunny weather.
#
# #**Insights:**
# - Fertilizer use has a consistent **positive impact on yield across all weather conditions.**
#
# - **Cloudy and sunny weather show stronger responses to fertilizer**, with a higher median yield when fertilizer is applied.
#
# - **Rainy conditions show a smaller difference** in yield between fertilizer use and non-use, implying that rainfall itself may provide significant nutritional support for crops.
#
# - Outliers, especially under sunny and cloudy conditions, suggest variable results in yield even with fertilizer.

# %% [markdown]
# #**Final Conclusion :**
#
#
#
# From the data analysis, several key insights have emerged:
#
# ###1. **Rainfall and Yield Relationship**:
#
# - There is a **positive correlation** between rainfall (Rainfall_mm) and crop yield (Yield_tons_per_hectare). Higher rainfall leads to increased yield, but the relationship shows variability, indicating that other factors, such as soil quality, irrigation, and fertilizer usage, play a role in determining yield outcomes.
#
#
# ###2. **Temperature’s Limited Impact**:
#
# - Temperature (Temperature_Celsius) shows no strong correlation with yield, suggesting that while important, it may not be a primary driver of productivity in this dataset. The wide range in temperature across samples implies other environmental or human factors have a more significant effect.
#
#
# ###3. **Fertilizer and Irrigation as Key Yield Drivers**:
#
# - The use of fertilizer and irrigation **significantly enhances crop yield**, particularly when these inputs are tailored to the crop's needs and local conditions. This pattern is seen across various crops and regions, with irrigated and fertilized fields consistently outperforming those that are not.
#
#
# ###4. **Soil and Region Compatibility**:
# - The data highlights the importance of **soil type** in conjunction with regional practices. For example, maize thrives in the North on loam soil, while rice flourishes in sandy soil in the South. This underscores the need to match crops to the soil type for maximum yield potential.
#
# ###5. **Weather’s Role in Crop Success**:
# -  Sunny weather conditions correlate with higher crop yields, while cloudy or rainy conditions lead to slightly lower yields. However, when irrigation is used in line with weather conditions, it compensates for less favorable conditions, ensuring higher productivity.

# %% [markdown]
# #**Recommendations:**
#
# ###1. **Optimize Water and Fertilizer Management**:
#
# - Since irrigation and fertilizer usage are critical for yield optimization, it is recommended to adopt **strategic water management practices** that consider local weather conditions and crop requirements. Balancing **irrigation and rainfall** can maximize crop output. Similarly, region-specific **fertilizer management** plans should be implemented to provide essential nutrients based on crop needs and soil conditions.
#
# ###2. **Focus on Rainfed Crops**:
#
# - While some regions rely heavily on irrigation, it is important to continue investing in rainfed crops, especially in areas with natural water availability. Further research into **rainfall patterns and soil moisture retention** could enhance productivity for crops grown without irrigation.
#
# ###3. **Adapt to Regional Conditions**:
#
# - Regional **crop planning** should consider the compatibility of crops with local soil and climate conditions. For instance, maize cultivation should be encouraged in areas with loam soil, while rice can be prioritized in regions with sandy soil. This ensures that farming practices are aligned with the natural advantages of each region.
#
#
# ###4. **Monitor and Adjust Based on Weather**:
#
# - Since weather conditions, especially **sunny days**, have a positive effect on yield, farmers should adopt **weather-responsive strategies**. This includes adjusting irrigation schedules, fertilizer applications, and other farming practices based on **weather forecasts** to maximize yield potential under varying conditions.
#
#
# ###4. **Explore Further Factors Affecting Yield Variability**:
# - The range of variability in yield for rainfall and temperature suggests there are other **underlying factors** contributing to the differences in crop production. Further investigation into factors such as **pest control, crop variety, and farming techniques** could provide deeper insights into yield optimization.
#
#
#
# By implementing these strategies, it will be possible to **enhance agricultural productivity**, **reduce variability in yield**, and ensure **sustainable farming practices** across different regions and weather conditions.

# %% [markdown]
# #**Conclusion :**
#
#
# In conclusion, this project has successfully demonstrated the importance of **Exploratory Data Analysis (EDA)** in uncovering meaningful insights from the dataset. Through careful examination of numeric and categorical data, we **identified key patterns, trends, and potential anomalies.** By addressing inconsistencies and cleaning the data, we ensured the foundation for accurate and reliable analysis.
#
#
#
# - The exploratory data analysis (EDA) performed in this project has provided valuable insights into the **relationships between key agricultural factors such as rainfall, temperature, days to harvest, soil type, and crop yield**. We observed that **rainfall plays a crucial role in determining crop yield, with higher rainfall** generally leading to increased productivity. However, the variability in yield across different rainfall ranges suggests that other factors, **like soil quality, irrigation, and fertilizer use, significantly influence the outcome.**
#
#
#
# - Additionally, we found that **temperature has a relatively weak correlation with yield, indicating that while important, it is not the sole driver of crop success.** Instead, fertilizer and irrigation emerged as critical factors, significantly improving yields, especially when tailored to the specific crop and regional needs. The study also highlighted the importance of soil type in crop selection, showing that different regions favor specific crops based on soil compatibility.
#
#
#
# - Moving forward, the findings from this EDA can be used to **inform agricultural policy**, guide **sustainable farming practices**, and improve yield optimization strategies. This project demonstrates the power of data-driven insights in **enhancing agricultural productivity**, ensuring better decision-making for farmers and stakeholders alike.
#
# - The findings from this exploration not only answered the initial questions posed but also provided a clear direction for future analysis. By leveraging visualizations and statistical summaries, we were able to generate actionable insights that will support data-driven decision-making and further hypothesis testing.
#
#
#
# **This project highlights the value of a well-structured EDA process as a critical step in transforming raw data into valuable information.**
